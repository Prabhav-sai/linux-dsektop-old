# %%
# poetNameDatePlace
import requests
import string
from bs4 import BeautifulSoup
list_char=[]
for letter in string.ascii_lowercase:
   list_char.append(str(letter))
list_char.remove("w")
list_char.remove("x")

# print(list_char)

# for c in list_char:
URL="https://www.rekhta.org/stories?startswith=a"
r = requests.get(URL)



soup = BeautifulSoup(r.content, 'html5lib') # If this line causes an error, run 'pip install html5lib' or install html5lib
table = soup.find_all(class_="poetNameDatePlace")
print(table)
for tab in table:
  link=tab.find_all('a')
  print(link[0].get('href'))
# Out:
# [<div class="poetNameDatePlace clearfix">
#                                 <a aria-label="A. Hameed" class="clearfix" href="https://www.rekhta.org/authors/a-hameed/stories" title="A. Hameed">
#                                     <h2>A. Hameed </h2>
#                                 </a>
#                         </div>, <div class="poetNameDatePlace clearfix">
#                                 <a aria-label="A. Khayyam" class="clearfix" href="https://www.rekhta.org/authors/a-khayyam-1/stories" title="A. Khayyam">
#                                     <h2>A. Khayyam </h2>
#                                 </a>
#                         </div>, <div class="poetNameDatePlace clearfix">
#                                 <a aria-label="Aagha Babar" class="clearfix" href="https://www.rekhta.org/authors/aagha-babar/stories" title="Aagha Babar">
#                                     <h2>Aagha Babar </h2>
#                                 </a>
# ...

# %%
URL="https://www.rekhta.org/authors/a-hameed/stories"
r = requests.get(URL)
soup = BeautifulSoup(r.content, 'html5lib') # If this line causes an error, run 'pip install html5lib' or install html5lib
table = soup.find_all(class_="nwPoetListBody")
for tab in table:
  link=tab.find_all('a')
  print(link[1].get('href'))
# Out:
# https://www.rekhta.org/stories/aur-pul-toot-gaya-a-hameed-stories
# https://www.rekhta.org/stories/mitti-ki-mona-liza-a-hameed-stories
# https://www.rekhta.org/stories/eik-raat-a-hameed-stories
# https://www.rekhta.org/stories/manzil-manzil-a-hameed-stories
# https://www.rekhta.org/stories/shaahdre-ki-eik-shaam-a-hameed-stories

# %%
import regex as re
URL="https://www.rekhta.org/stories/mitti-ki-mona-liza-a-hameed-stories"
r = requests.get(URL)
soup = BeautifulSoup(r.content, 'html5lib') # If this line causes an error, run 'pip install html5lib' or install html5lib
table = soup.find_all(class_="mainContentBody")[0].find_all('input')[0]
final_string=str(table).split()

import codecs,string

def detect_language(character):
    maxchar = max(character)
    if u'\u0900' <= maxchar <= u'\u097f':
        return 'hindi'
print(final_string)
for i in final_string:
    isEng = detect_language(i)
    if isEng == "hindi":
        print(i.split(';')[1],end=" ")
print()
# Out:
# ['<input', 'data-hidden="&lt;div', "class='pMC'", "data-roman='off'", "data-pc='57'&gt;&lt;div", "class='w'", "data-p='1'&gt;&lt;div", "class='c'&gt;&lt;p", "data-l='1'&gt;&lt;span", "data-m='6TQen6tPZPvz6epY+5ZHtQ=='&gt;मोना", '&lt;/span&gt;&lt;span', "data-m='b4XbqYn14o9UliGxlDZnrA=='&gt;लीज़ा", '&lt;/span&gt;&lt;span', "data-m='Sy4/63XI4Y2X/B/knnLreg=='&gt;की", '&lt;/span&gt;&lt;span', "data-m='hYZNobuf+vzWN5bkchvkf+JQED5juGGQdHjYFw7L71k='&gt;मुस्कुराहट", '&lt;/span&gt;&lt;span', "data-m='Bq27PSwRjhafQXoCm7ZLfA=='&gt;में", '&lt;/span&gt;&lt;span', "data-m='zalI4FSrSF2xU1TxhP7Nmg=='&gt;क्या", '&lt;/span&gt;&lt;span', "data-m='Vnh04GiIMjooGX2m9eFrqQ=='&gt;भेद", '&lt;/span&gt;&lt;span', "data-m='8WPegHWYhWlBNSohhCBb7A=='&gt;है?", '&lt;/span&gt;&lt;/p&gt;&lt;/div&gt;&lt;/div&gt;&lt;div', "class='w'", "data-p='2'&gt;&lt;div", "class='c'&gt;&lt;p", "data-l='2'&gt;&lt;span", "data-m='C8/CgN6QGQh6RHxEUoe1Dw=='&gt;उसके", '&lt;/span&gt;&lt;span', "data-m='vvrkjqo/cbOuU0N3Gyys5FZCTGIlujkUw+H
# ...
