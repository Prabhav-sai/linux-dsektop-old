# %%
import re
from nltk.corpus import stopwords
from collections import defaultdict
from nltk.stem import SnowballStemmer
from nltk.stem import WordNetLemmatizer

# %%
filename = "Census_1951_Vol1_Part1A.txt"
infile = open(filename,'r')
text = infile.read()
infile.close()

# %%
print(text[:100])
# Out:
# CENSUS OF INDIA, 1951
# VOLUME I
#
# IN 0 I A
# PAHT I-A -
#
# REPOI~T
#
# R. A. GOPALASW AMI,
# OF ITIE INDIAN CIV

# %%
#Tokenise

unrefinedStr = re.sub(r'\—|\'|\`|\"|\||\.|\*|\[|\{|\}|\(|\)|\]|\;|\:|\,|\^|\=|\-|\+|\_|\!|\?|\/|\>|\<|\&|\\|\#|\n', r' ', text) # removing special characters

# %%
print(unrefinedStr)
# Out:
# CENSUS OF INDIA  1951 VOLUME I  IN 0 I A PAHT I A    REPOI~T  R  A  GOPALASW AMI  OF ITIE INDIAN CIVIL SERVICE   Registrar General  India and ex officio Ce1lSus Commissioner for India  p    CC  48  I  I a    000  Prl    e Ordinary  Delu re PART I A    Report  Rs  10   or 16 sh   Rs  3   or 5 sh   PART I B  Appendices  Rs  10   or 16 sh   Rs  3   or 5 sl1   PARTS I A   I B  coinbined   Rs  15   or 23 sh 6 d  R     5   or 8 sh   PRINTED I i  NDIA BY THE MANAGER  GOVT  OF INnIA PRESS  NEW DELHI  AND PUBLISHED  DY  THE  MANAGER  OF  PU8UCATIONS   DELHl   1953  FEW PEOPLE OUTSIDE realise that census is  an administrative operation oj great di mensions and  in additi on  it is a sci rmific process  Indian census  in particular  covers the largest populati on in the  World and it is also one of the most economical administrative operations  Census as an institution goes back to the remote past  but it is no longer a mere counting of heads  it involves extraction of information which plays a vital role in the determimuion of many of our administrative policies  The facts el£czted during the course of this operation yield valuable scientific data of sociological importance  In many matters it provides a useful guide for the effectiveness or otherwise of our economic policies  The theory of population is in itself an interesting part of economics  The census helps us to test and adapt that theory  0 facts     SJrd r VALLABHBIIAI PATH  No  51Is9 53 RG THE REGISTRAR GENERAL  INDIA  New Delhi  the 1st August  1953  From  Shri R A  Gopalaswami  I e s   Registrar General  India   and ex oifi cio Census Commissioner for India  To The Secretary to the Government of India  Ministry of Home Affairs  New Delhi  Sir  I have t he honour to submit herewith my report on the 1951 Census   Yours faithfully   R  A  GOPALASWAMI  Registrar General  India  and ex officio Census Commissioner for India  INTRODUCTION 1  The 1951 Census Reports  The reports on the 1951 Census Ole issued in 17 volwnes  which are divided into 63 parts  The first of these volumes contains the All India Census Report  It is divided into five parts entitled  PART I  A REpoRT   PART I·B APPENDICES TO THE REpORT  PART II·A DEMOGRAPHIC TABLES  PART II B EcONOMIC TABLES  General Population   PART lI C EcONOMIC TABLES  Rural and Urban Population    The other volumes which are divided into 58 parts  contain the State Census Reports  These are prepared by my colleagues  the Superintendents of Census Operations  in different states as shown below·   Volume  Number  number   If parts  Shri RAJESHWARI PRASAD  l A S   II  5  Uttar Pradesh  Shri S  VENKATESWARAN  I C S   III  3  Madras and Coorg  Mr  J  B  BOWMAN  I C S   IV  3  Bombay   V  3  Bihar  VI  6  West Bengal and  Name of Superintendent  Name of state s   rashtra  Sauand  Kutch Shri RANCHOR PRASAD  I A S  Shri AsOl  MITRA  I C S   •  •  •  •  •  Sikkim               ~  • All reports except the following have been or arc being published   i  The following parts of reports are in the press  Report and Subsidiary Tables BOMBAY PART I   Demographic  Social and Cultural Tables PART II A • Subsidiary Tables PART I C    WEST BENGAL Calcutta Report and Tables PARTS III and IV • Subsidiary Tables PART I B Economic  Household   Age  Sample  Table  PA RT II B • Report PART I·A   RAJASTHAN  Subsidiary Tables PART I·B Report and Subsidiary Table  PART I ORISSA Report PART I A AsSAM Subsidiary Tables PART J·B •   PART IT A and H B Tablet PART I A   • Report  l lIAvANCORJI CocIuN • Subsidiary Table  PART I B Tablel PAIlTU  it  Shri J  D  KERAWALLA  I A S   Died on 7 10 1952   VII  6  Madhya Pradesh  Shri LAKSHMI CHANDRA VASHISHTHA  of Punjab Civil Service •  VIII  4  Punjab  PEPSU  Delhi  Himachal Pradesh and Bilaspur  IX  4  Hyderabad  X  5 Rajasthanand  Shri C  K  MURrnY  I A S  Shri YAMUNA LAL DASHORA  Ajmer  Shri M AHMEn  of Orissa Civil Service  XI  3  Orissa  Shri R  B  VAGHAIWALLA  I C S   XII  4  Assam  Manipur and Tripura  Dr  U  S  NAIR   ...

# %%
tokens = unrefinedStr.split()

# %%
print(len(tokens))
print(tokens[:20])#print(tokens[0:20:1])
# Out:
# 113032
# ['CENSUS', 'OF', 'INDIA', '1951', 'VOLUME', 'I', 'IN', '0', 'I', 'A', 'PAHT', 'I', 'A', 'REPOI~T', 'R', 'A', 'GOPALASW', 'AMI', 'OF', 'ITIE']

# %%
tokens = [myword.lower() for myword in tokens]

# %%
print(tokens[:20])
# Out:
# ['census', 'of', 'india', '1951', 'volume', 'i', 'in', '0', 'i', 'a', 'paht', 'i', 'a', 'repoi~t', 'r', 'a', 'gopalasw', 'ami', 'of', 'itie']

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/prabhav/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
mystopwords = set(stopwords.words("english"))
print(len(mystopwords))
print(mystopwords)
# Out:
# 179
# {'more', 'just', 'few', 'yourselves', "wouldn't", 'herself', "doesn't", 'an', 'for', 'aren', 'its', 's', 'but', 'isn', 'itself', 'of', "didn't", 'can', 'he', 'theirs', "weren't", 'up', 'from', 'over', 'any', 'y', 'same', 'm', 'couldn', 'own', 'won', 'myself', 'each', 'to', 'yours', 'hers', "shan't", "hadn't", 'you', "you'll", 'this', 'were', 'on', 'ours', 'their', "hasn't", 'd', 'how', 'very', 'not', 'into', 'our', 'is', 'which', 'as', 'have', 'further', 'by', 'only', 'had', "won't", 'ain', 'ma', 'having', 'mightn', "haven't", "shouldn't", "she's", 'because', "mightn't", 'doing', 'your', 'again', 'been', 'here', 'wasn', 'or', 'themselves', 'them', 'no', 'do', "that'll", 'while', 'why', 'they', 'such', 'who', 'was', 'against', 'hadn', 'himself', "you'd", "should've", 'mustn', 'shouldn', 'there', "mustn't", 'we', "you've", 'if', 'her', 'where', 'that', 'and', 'has', 'those', "wasn't", 've', 'during', 'in', 'o', 'about', 'will', 'haven', 'i', 'does', 'yourself', 'don', 'weren', 'under', 'below', 'when', 'all', 'so', 'above', 't', 'didn', 'be', 'me', 'out', 'hasn', 'what', "isn't", 'doesn', 're', 'my', 'shan', 'now', 'down', 'wouldn', 'she', 'it', 'the', 'his', "aren't", 'until', 'too', 'once', 'am', 'nor', 'with', 'than', 'needn', "couldn't", 'did', 'through', 'at', 'both', 'some', "don't", 'other', 'then', 'after', 'should', "needn't", 'these', 'a', 'before', 'whom', 'off', 'between', 'are', 'll', 'most', "you're", "it's", 'being', 'him', 'ourselves'}

# %%
#stopwordsdict={}
#for stop in mystopwords:
#    stopwordsdict[stop] = 1

# %%
Bag=[]
for word in tokens:
    if word not in mystopwords and word.isnumeric()==False and len(word)>2:
        Bag.append(word)

# %%
print(len(Bag))
# Out:
# 55627

# %%
SnowStem = SnowballStemmer('english')
Lemmatiser = WordNetLemmatizer()

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /home/prabhav/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
Stembag = []
Lembag = []
for word in Bag:
    Stembag.append(SnowStem.stem(word))
    Lembag.append(Lemmatiser.lemmatize(word))

# %%
print(Bag[:20])
print(Stembag[:20])
print(Lembag[:20])
# Out:
# ['census', 'india', 'volume', 'paht', 'repoi~t', 'gopalasw', 'ami', 'itie', 'indian', 'civil', 'service', 'registrar', 'general', 'india', 'officio', 'ce1lsus', 'commissioner', 'india', 'prl', 'ordinary']
# ['census', 'india', 'volum', 'paht', 'repoi~t', 'gopalasw', 'ami', 'iti', 'indian', 'civil', 'servic', 'registrar', 'general', 'india', 'officio', 'ce1lsus', 'commission', 'india', 'prl', 'ordinari']
# ['census', 'india', 'volume', 'paht', 'repoi~t', 'gopalasw', 'ami', 'itie', 'indian', 'civil', 'service', 'registrar', 'general', 'india', 'officio', 'ce1lsus', 'commissioner', 'india', 'prl', 'ordinary']

# %%
mydict = {}
for word in Stembag:
    if word in mydict.keys():
        mydict[word] +=1
    else:
        mydict[word] = 1

# %%
mydict1 = {}
for word in Lembag:
    if word in mydict1.keys():
        mydict1[word] +=1
    else:
        mydict1[word] = 1

# %%
print(mydict)
# Out:
# {'census': 282, 'india': 1076, 'volum': 5, 'paht': 1, 'repoi~t': 1, 'gopalasw': 1, 'ami': 1, 'iti': 2, 'indian': 46, 'civil': 6, 'servic': 92, 'registrar': 7, 'general': 106, 'officio': 4, 'ce1lsus': 1, 'commission': 9, 'prl': 1, 'ordinari': 6, 'delu': 1, 'part': 262, 'report': 115, 'appendic': 5, 'sl1': 1, 'coinbin': 1, 'print': 23, 'ndia': 1, 'manag': 15, 'govt': 6, 'innia': 1, 'press': 21, 'new': 70, 'delhi': 20, 'publish': 31, 'pu8uc': 1, 'delhl': 1, 'peopl': 335, 'outsid': 5, 'realis': 14, 'administr': 32, 'oper': 45, 'great': 77, 'mension': 1, 'additi': 1, 'sci': 1, 'rmific': 1, 'process': 26, 'particular': 34, 'cover': 25, 'largest': 14, 'populati': 1, 'world': 123, 'also': 178, 'one': 319, 'econom': 59, 'institut': 13, 'goe': 3, 'back': 10, 'remot': 2, 'past': 31, 'longer': 15, 'mere': 26, 'count': 52, 'head': 32, 'involv': 22, 'extract': 17, 'inform': 55, 'play': 5, 'vital': 10, 'role': 5, 'determimuion': 1, 'mani': 70, 'polici': 13, 'fact': 106, 'el£czt': 1, 'cours': 29, 'yield': 71, 'valuabl': 5, 'scientif': 5, 'data': 139, 'sociolog': 1, 'import': 135, 'matter': 25, 'provid': 52, 'use': 134, 'guid': 1, 'effect': 51, 'otherwis': 11, 'theori': 5, 'popul': 391, 'interest': 15, 'help': 33, 'test': 8, 'adapt': 3, 'sjrd': 1, 'vallabhbiiai': 1, 'path': 1, '51is9': 1, '1st': 8, 'august': 4, 'shri': 35, 'gopalaswami': 3, 'oifi': 1, 'cio': 1, 'secretari': 1, 'govern': 115, 'ministri': 11, 'home': 7, 'affair': 6, 'sir': 1, 'honour': 2, 'submit': 3, 'herewith': 1, 'faith': 4, 'introduct': 3, 'ole': 1, 'issu': 17, 'volwn': 1, 'divid': 35, 'first': 133, 'contain': 33, 'five': 82, 'entitl': 6, 'i·b': 2, 'ii·a': 1, 'demograph': 6, 'tabl': 264, 'rural': 55, 'urban': 58, 'state': 216, 'prepar': 34, 'colleagu': 6, 'superintend': 12, 'differ': 289, 'shown': 62, 'below·': 1, 'number': 419, 'rajeshwari': 1, 'prasad': 2, 'uttar': 81, 'pradesh': 190, 'venkateswaran': 1, 'iii': 106, 'madra': 106, 'coorg': 10, 'bowman': 1, 'bombay': 99, 'bihar': 36, 'west': 312, 'bengal': 53, 'name': 13, 'rashtra': 1, 'sauand': 1, 'kutch': 15, 'ranchor': 1, 'asol': 1, 'mitra': 1, 'sikkim': 10, 'except': 53, 'follow': 138, 'arc': 55, 'subsidiari': 17, 'social': 31, 'cultur': 9, 'calcutta': 20, 'household': 116, 'age': 230, 'sampl': 16, 'i·a': 2, 'rajasthan': 34, 'orissa': 40, 'assam': 31, 'j·b': 2, 'tablet': 1, 'liavancorji': 1, 'cociun': 1, 'tablel': 1, 'pailtu': 1, 'kerawalla': 2, 'die': 23, 'vii': 15, 'madhya': 117, 'lakshmi': 1, 'chandra': 1, 'vashishtha': 1, 'punjab': 47, 'viii': 7, 'pepsu': 1, 'himach': 7, 'bilaspur': 9, 'hyderabad': 29, 'rajasthanand': 1, 'murrni': 1, 'yamuna': 1, 'lal': 5, 'dashora': 1, 'ajmer': 15, 'ahmen': 1, 'vaghaiwalla': 1, 'xii': 2, 'manipur': 10, 'tripura': 8, 'nair': 1, 'xiii': 2, 'travancorecochin': 2, 'mallaradhya': 1, 's••': 1, 'xiv': 2, 'mysor': 25, 'ranglal': 1, 'dube': 1, 'ghosh': 1, 'xvi': 3, 'vindhya': 13, 'xvii': 2, 'andaman': 6, 'bharat': 22, 'bhopal': 10, 'nicobar': 6, 'island': 8, 'district': 117, 'handbook': 5, 'addit': 36, 'compil': 20, 'relat': 140, 'footnou': 1, 'col': 2, 'cll': 1, 'ded': 1, '~1yoorb': 1, 'dharat': 2, 'lya': 1, 'lreparatlon': 1, 'nearina': 1, 'complet': 66, 'utrar': 1, 'pradesr': 1, 'idbrabad': 1, 'mvsorb': 1, 'sharat': 1, 'nioobaa': 1, 'biel': 1, 'ill': 25, 'separ': 53, 'statist': 90, 'local': 38, 'area': 438, 'within': 68, 'well': 110, 'basic': 17, 'total': 176, 'eight': 13, 'livelihood': 99, 'class': 93, 'everi': 125, 'villag': 174, 'ward': 4, 'town': 159, 'district·': 1, 'public': 69, 'inciud': 1, 'item': 12, 'could': 41, 'readili': 4, 'assembl': 3, 'seem': 57, 'like': 55, 'purpos': 48, 'refer': 61, 'hundr': 31, 'twelv': 5, 'alreadi': 76, 'other': 28, 'brochur': 6, 'note': 51, 'limit': 70, 'countri': 226, 'whole': 105, 'type': 49, 'seri': 11, 'self': 76, 'paper': 21, 'present': 112, 'relev': 30, 'minimum': 6, 'introductori': 3, 'requir': 38, 'proper': 7, 'understand': 10, 'includ': 117, 'summari': 4, 'found': 73, 'necessari': 75, 'make': 84, 'avail': 77, 'publil': 1, 'advanc': 16, 'main':  ...

# %%
print(mydict1)
# Out:
# {'census': 282, 'india': 1076, 'volume': 5, 'paht': 1, 'repoi~t': 1, 'gopalasw': 1, 'ami': 1, 'itie': 1, 'indian': 46, 'civil': 6, 'service': 92, 'registrar': 7, 'general': 80, 'officio': 4, 'ce1lsus': 1, 'commissioner': 9, 'prl': 1, 'ordinary': 6, 'delu': 1, 'part': 257, 'report': 105, 'appendix': 48, 'sl1': 1, 'coinbined': 1, 'printed': 16, 'ndia': 1, 'manager': 4, 'govt': 6, 'innia': 1, 'press': 19, 'new': 70, 'delhi': 20, 'published': 25, 'pu8ucations': 1, 'delhl': 1, 'people': 335, 'outside': 5, 'realise': 7, 'administrative': 14, 'operation': 30, 'great': 71, 'mensions': 1, 'additi': 1, 'sci': 1, 'rmific': 1, 'process': 13, 'particular': 29, 'cover': 15, 'largest': 14, 'populati': 1, 'world': 123, 'also': 178, 'one': 318, 'economical': 1, 'institution': 6, 'go': 3, 'back': 9, 'remote': 1, 'past': 31, 'longer': 15, 'mere': 2, 'counting': 2, 'head': 30, 'involves': 8, 'extraction': 2, 'information': 55, 'play': 3, 'vital': 5, 'role': 5, 'determimuion': 1, 'many': 69, 'policy': 13, 'fact': 106, 'el£czted': 1, 'course': 29, 'yield': 53, 'valuable': 5, 'scientific': 3, 'data': 139, 'sociological': 1, 'importance': 15, 'matter': 25, 'provides': 6, 'useful': 12, 'guide': 1, 'effectiveness': 3, 'otherwise': 11, 'economic': 52, 'theory': 5, 'population': 387, 'interesting': 2, 'economics': 2, 'help': 23, 'test': 6, 'adapt': 2, 'sjrd': 1, 'vallabhbiiai': 1, 'path': 1, '51is9': 1, '1st': 8, 'august': 4, 'shri': 35, 'gopalaswami': 3, 'oifi': 1, 'cio': 1, 'secretary': 1, 'government': 109, 'ministry': 11, 'home': 7, 'affair': 6, 'sir': 1, 'honour': 2, 'submit': 2, 'herewith': 1, 'faithfully': 1, 'introduction': 3, 'ole': 1, 'issued': 8, 'volwnes': 1, 'divided': 27, 'first': 133, 'contains': 9, 'five': 82, 'entitled': 6, 'i·b': 2, 'ii·a': 1, 'demographic': 6, 'table': 264, 'rural': 55, 'urban': 57, 'contain': 8, 'state': 207, 'prepared': 17, 'colleague': 6, 'superintendent': 12, 'different': 149, 'shown': 62, 'below·': 1, 'number': 406, 'rajeshwari': 1, 'prasad': 2, 'uttar': 81, 'pradesh': 190, 'venkateswaran': 1, 'iii': 106, 'madras': 105, 'coorg': 10, 'bowman': 1, 'bombay': 99, 'bihar': 36, 'west': 312, 'bengal': 53, 'name': 9, 'rashtra': 1, 'sauand': 1, 'kutch': 15, 'ranchor': 1, 'asol': 1, 'mitra': 1, 'sikkim': 10, 'except': 36, 'following': 64, 'arc': 55, 'subsidiary': 17, 'social': 31, 'cultural': 7, 'calcutta': 20, 'household': 116, 'age': 202, 'sample': 14, 'i·a': 2, 'rajasthan': 34, 'orissa': 40, 'assam': 31, 'j·b': 2, 'tablet': 1, 'liavancorji': 1, 'cociun': 1, 'tablel': 1, 'pailtu': 1, 'kerawalla': 2, 'died': 10, 'vii': 15, 'madhya': 117, 'lakshmi': 1, 'chandra': 1, 'vashishtha': 1, 'punjab': 47, 'viii': 7, 'pepsu': 1, 'himachal': 7, 'bilaspur': 9, 'hyderabad': 29, 'rajasthanand': 1, 'murrny': 1, 'yamuna': 1, 'lal': 5, 'dashora': 1, 'ajmer': 15, 'ahmen': 1, 'vaghaiwalla': 1, 'xii': 2, 'manipur': 10, 'tripura': 8, 'nair': 1, 'xiii': 2, 'travancorecochin': 2, 'mallaradhya': 1, 's••': 1, 'xiv': 2, 'mysore': 25, 'ranglal': 1, 'dube': 1, 'ghosh': 1, 'xvi': 3, 'vindhya': 12, 'xvii': 2, 'andaman': 6, 'bharat': 22, 'bhopal': 10, 'nicobar': 6, 'island': 8, 'district': 116, 'handbook': 5, 'addition': 31, 'compiled': 13, 'relates': 5, 'footnou': 1, 'col': 2, 'cll': 1, 'ded': 1, '~1yoorb': 1, 'dharat': 2, 'lya': 1, 'lreparatlon': 1, 'nearina': 1, 'completion': 5, 'utrar': 1, 'pradesr': 1, 'idbrabad': 1, 'mvsorb': 1, 'sharat': 1, 'nioobaa': 1, 'biel': 1, 'ill': 24, 'separately': 27, 'statistic': 66, 'relating': 35, 'local': 32, 'area': 438, 'within': 68, 'well': 110, 'basic': 17, 'total': 174, 'eight': 13, 'separate': 15, 'livelihood': 99, 'class': 87, 'every': 125, 'village': 165, 'ward': 4, 'town': 159, 'district·': 1, 'publication': 10, 'inciud': 1, 'item': 12, 'could': 41, 'readily': 4, 'assembled': 2, 'seemed': 6, 'likely': 40, 'purpose': 48, 'reference': 26, 'hundred': 31, 'twelve': 5, 'already': 76, 'others': 28, 'brochure': 6, 'noted': 22, 'statistical': 23, 'contained': 13, 'limited': 24, 'country': 226, 'whole': 105, 'type': 4 ...

# %%
sortedDict = sorted(mydict.items(),key=lambda x:x[1],reverse=True)
print(sortedDict[:100])
# Out:
# [('india', 1076), ('per', 515), ('land', 473), ('cent', 440), ('area', 438), ('lakh', 437), ('number', 419), ('popul', 391), ('rate', 342), ('peopl', 335), ('year', 334), ('one', 319), ('cultiv', 313), ('west', 312), ('north', 297), ('divis', 292), ('birth', 290), ('differ', 289), ('census', 282), ('tabl', 264), ('part', 262), ('figur', 254), ('age', 230), ('sub', 227), ('countri', 226), ('increas', 221), ('may', 221), ('state', 216), ('south', 213), ('person', 203), ('growth', 203), ('zone', 195), ('region', 195), ('pradesh', 190), ('also', 178), ('total', 176), ('acr', 175), ('villag', 174), ('two', 173), ('town', 159), ('central', 152), ('east', 152), ('among', 151), ('capita', 149), ('live', 149), ('proport', 149), ('death', 148), ('agricultur', 148), ('irrig', 146), ('relat', 140), ('data', 139), ('follow', 138), ('three', 137), ('import', 135), ('use', 134), ('chapter', 134), ('femal', 134), ('first', 133), ('product', 133), ('larg', 133), ('decad', 131), ('would', 130), ('averag', 130), ('much', 129), ('develop', 129), ('male', 129), ('plain', 127), ('everi', 125), ('world', 123), ('even', 123), ('percentag', 119), ('group', 118), ('madhya', 117), ('district', 117), ('includ', 117), ('food', 117), ('household', 116), ('report', 115), ('govern', 115), ('small', 113), ('present', 112), ('time', 112), ('natur', 111), ('well', 110), ('last', 110), ('order', 110), ('matern', 109), ('result', 108), ('general', 106), ('fact', 106), ('iii', 106), ('madra', 106), ('less', 106), ('possibl', 106), ('whole', 105), ('work', 104), ('crore', 103), ('show', 103), ('mean', 102), ('bombay', 99)]

# %%
for x in sortedDict[:100]:
    print(x)
# Out:
# ('india', 1076)
# ('per', 515)
# ('land', 473)
# ('cent', 440)
# ('area', 438)
# ('lakh', 437)
# ('number', 406)
# ('population', 387)
# ('rate', 339)
# ('people', 335)
# ('year', 332)
# ('one', 318)
# ('west', 312)
# ('north', 297)
# ('division', 292)
# ('birth', 290)
# ('census', 282)
# ('table', 264)
# ('part', 257)
# ('figure', 254)
# ('sub', 227)
# ('country', 226)
# ('may', 221)
# ('south', 213)
# ('state', 207)
# ('growth', 203)
# ('age', 202)
# ('zone', 195)
# ('region', 195)
# ('person', 191)
# ('pradesh', 190)
# ('also', 178)
# ('acre', 175)
# ('total', 174)
# ('two', 173)
# ('village', 165)
# ('town', 159)
# ('central', 152)
# ('east', 152)
# ('among', 151)
# ('different', 149)
# ('caput', 149)
# ('proportion', 149)
# ('death', 148)
# ('child', 148)
# ('increase', 142)
# ('data', 139)
# ('three', 137)
# ('chapter', 134)
# ('first', 133)
# ('female', 133)
# ('decade', 131)
# ('would', 130)
# ('much', 129)
# ('male', 129)
# ('average', 127)
# ('plain', 127)
# ('every', 125)
# ('agricultural', 125)
# ('difference', 125)
# ('world', 123)
# ('large', 120)
# ('percentage', 119)
# ('even', 119)
# ('madhya', 117)
# ('food', 117)
# ('household', 116)
# ('district', 116)
# ('cultivation', 115)
# ('group', 111)
# ('well', 110)
# ('order', 110)
# ('small', 110)
# ('government', 109)
# ('time', 109)
# ('last', 108)
# ('le', 107)
# ('fact', 106)
# ('iii', 106)
# ('report', 105)
# ('madras', 105)
# ('whole', 105)
# ('maternity', 105)
# ('crore', 103)
# ('development', 103)
# ('irrigation', 101)
# ('bombay', 99)
# ('livelihood', 99)
# ('woman', 99)
# ('period', 98)
# ('mean', 97)
# ('result', 96)
# ('must', 95)
# ('belt', 94)
# ('service', 92)
# ('show', 91)
# ('ratio', 91)
# ('soil', 90)
# ('present', 89)
# ('level', 89)

# %%
sortedDict = sorted(mydict1.items(),key=lambda x:x[1],reverse=True)
print(sortedDict[:100])
# Out:
# [('india', 1076), ('per', 515), ('land', 473), ('cent', 440), ('area', 438), ('lakh', 437), ('number', 406), ('population', 387), ('rate', 339), ('people', 335), ('year', 332), ('one', 318), ('west', 312), ('north', 297), ('division', 292), ('birth', 290), ('census', 282), ('table', 264), ('part', 257), ('figure', 254), ('sub', 227), ('country', 226), ('may', 221), ('south', 213), ('state', 207), ('growth', 203), ('age', 202), ('zone', 195), ('region', 195), ('person', 191), ('pradesh', 190), ('also', 178), ('acre', 175), ('total', 174), ('two', 173), ('village', 165), ('town', 159), ('central', 152), ('east', 152), ('among', 151), ('different', 149), ('caput', 149), ('proportion', 149), ('death', 148), ('child', 148), ('increase', 142), ('data', 139), ('three', 137), ('chapter', 134), ('first', 133), ('female', 133), ('decade', 131), ('would', 130), ('much', 129), ('male', 129), ('average', 127), ('plain', 127), ('every', 125), ('agricultural', 125), ('difference', 125), ('world', 123), ('large', 120), ('percentage', 119), ('even', 119), ('madhya', 117), ('food', 117), ('household', 116), ('district', 116), ('cultivation', 115), ('group', 111), ('well', 110), ('order', 110), ('small', 110), ('government', 109), ('time', 109), ('last', 108), ('le', 107), ('fact', 106), ('iii', 106), ('report', 105), ('madras', 105), ('whole', 105), ('maternity', 105), ('crore', 103), ('development', 103), ('irrigation', 101), ('bombay', 99), ('livelihood', 99), ('woman', 99), ('period', 98), ('mean', 97), ('result', 96), ('must', 95), ('belt', 94), ('service', 92), ('show', 91), ('ratio', 91), ('soil', 90), ('present', 89), ('level', 89)]

# %%
for x in sortedDict[:100]:
    print(x)
# Out:
# ('india', 1076)
# ('per', 515)
# ('land', 473)
# ('cent', 440)
# ('area', 438)
# ('lakh', 437)
# ('number', 406)
# ('population', 387)
# ('rate', 339)
# ('people', 335)
# ('year', 332)
# ('one', 318)
# ('west', 312)
# ('north', 297)
# ('division', 292)
# ('birth', 290)
# ('census', 282)
# ('table', 264)
# ('part', 257)
# ('figure', 254)
# ('sub', 227)
# ('country', 226)
# ('may', 221)
# ('south', 213)
# ('state', 207)
# ('growth', 203)
# ('age', 202)
# ('zone', 195)
# ('region', 195)
# ('person', 191)
# ('pradesh', 190)
# ('also', 178)
# ('acre', 175)
# ('total', 174)
# ('two', 173)
# ('village', 165)
# ('town', 159)
# ('central', 152)
# ('east', 152)
# ('among', 151)
# ('different', 149)
# ('caput', 149)
# ('proportion', 149)
# ('death', 148)
# ('child', 148)
# ('increase', 142)
# ('data', 139)
# ('three', 137)
# ('chapter', 134)
# ('first', 133)
# ('female', 133)
# ('decade', 131)
# ('would', 130)
# ('much', 129)
# ('male', 129)
# ('average', 127)
# ('plain', 127)
# ('every', 125)
# ('agricultural', 125)
# ('difference', 125)
# ('world', 123)
# ('large', 120)
# ('percentage', 119)
# ('even', 119)
# ('madhya', 117)
# ('food', 117)
# ('household', 116)
# ('district', 116)
# ('cultivation', 115)
# ('group', 111)
# ('well', 110)
# ('order', 110)
# ('small', 110)
# ('government', 109)
# ('time', 109)
# ('last', 108)
# ('le', 107)
# ('fact', 106)
# ('iii', 106)
# ('report', 105)
# ('madras', 105)
# ('whole', 105)
# ('maternity', 105)
# ('crore', 103)
# ('development', 103)
# ('irrigation', 101)
# ('bombay', 99)
# ('livelihood', 99)
# ('woman', 99)
# ('period', 98)
# ('mean', 97)
# ('result', 96)
# ('must', 95)
# ('belt', 94)
# ('service', 92)
# ('show', 91)
# ('ratio', 91)
# ('soil', 90)
# ('present', 89)
# ('level', 89)
