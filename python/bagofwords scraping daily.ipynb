# %%
import re
from nltk.corpus import stopwords
from collections import defaultdict
from nltk.stem import SnowballStemmer
from nltk.stem import WordNetLemmatizer

# %%
filename = "DailNews.txt"
infile = open(filename,'r')
text = infile.read()
infile.close()

# %%
print(text[:100])
# Out:
# A 71-year-old Illinois man accused of fatally stabbing a 6-year-old boy and seriously wounding a 32

# %%
#Tokenise

unrefinedStr = re.sub(r'\—|\'|\`|\"|\||\.|\*|\[|\{|\}|\(|\)|\]|\;|\:|\,|\^|\=|\-|\+|\_|\!|\?|\/|\>|\<|\&|\\|\#|\n', r' ', text) # removing special characters

# %%
print(unrefinedStr)
# Out:
#  A 71 year old Illinois man accused of fatally stabbing a 6 year old boy and seriously wounding a 32 year old woman was charged with a hate crime Sunday  Police allege he singled out the victims because of their Islamic faith and as a response to the war between Israel and Hamas In recent days  police in US cities and federal authorities have been on high alert for violence driven by antisemitic or Islamophobic sentiments  FBI officials  along with Jewish and Muslim groups  have reported an increase of hateful and threatening rhetoric In the Chicago area case  officers found the woman and boy late Saturday morning at a home in an unincorporated area of Plainfield Township  about 40 miles  65 kilometers  southwest of Chicago  the Will County Sheriff s Office said in a statement on social media The boy was pronounced dead at a hospital  The woman had multiple stab wounds and was expected to survive  according to the statement  An autopsy on the child showed he had been stabbed dozens of times “Detectives were able to determine that both victims in this brutal attack were targeted by the suspect due to them being Muslim and the on going Middle Eastern conflict involving Hamas and the Israelis ” the sheriff s statement said According to the Will County sheriff s office  the woman had called 911 to report that her landlord had attacked her with a knife  adding she then ran into a bathroom and continued to fight him off The man suspected in the attack was found Saturday outside the home and “sitting upright outside on the ground near the driveway of the residence” with a cut on his forehead  authorities said Joseph M  Czuba of Plainfield was charged with first degree murder  attempted first degree murder  two counts of hate crimes and aggravated battery with a deadly weapon  according to the sheriff s office  He was in custody Sunday and awaiting a court appearance Attempts to reach Czuba or a family member were unsuccessful Sunday  His home phone number was unlisted  Messages left for possible relatives in online records and on social media were not immediately returned  The sheriff s office and county public defender s office did not immediately return messages about Czuba s legal representation Authorities did not release the names of the two victims But the boy s paternal uncle  Yousef Hannon  spoke at a news conference Sunday hosted by the Chicago chapter Council on American Islamic Relations  There the boy was identified as Wadea Al Fayoume  a Palestinian American boy who recently had turned 6  The organisation identified the other victim as the boy s mother “We are not animals  we are humans  We want people to see us as humans  to feel us as humans  to deal with us as humans  because this is what we are ” said Hannon  a Palestinian American who emigrated to the U S  In 1999 to work  including as a public school teacher The Muslim civil liberties organisation called the crime “our worst nightmare” and part of a disturbing spike in hate calls and emails since the outbreak of the Israel Hamas war  The group cited text messages exchanged among family members that showed the attacker had made disparaging remarks about Muslims “Palestinians basically  again  with their hearts broken over what s happening to their people ” said Ahmed Rehab  the group s executive director  “have to also worry about the immediate safety of life and limb living here in this most free of democracies in the world  In response to the increased threats  the Illinois State Police are communicating with federal law enforcement and reaching out to Muslim communities and religious leaders to offer support  according to a Sunday press release from Illinois Democratic Gov  JB Pritzker “To take a six year old child s life in the name of bigotry is nothing short of evil   Pritzker said   Wadea should be heading to school in the morning  Instead  his parents will wake up without their son  This wasn t just a murder   it was a hate crime  And every single Illinoisan ...

# %%
tokens = unrefinedStr.split()

# %%
print(len(tokens))
print(tokens[:20])#print(tokens[0:20:1])
# Out:
# 44497
# ['A', '71', 'year', 'old', 'Illinois', 'man', 'accused', 'of', 'fatally', 'stabbing', 'a', '6', 'year', 'old', 'boy', 'and', 'seriously', 'wounding', 'a', '32']

# %%
tokens = [myword.lower() for myword in tokens]

# %%
print(tokens[:20])
# Out:
# ['a', '71', 'year', 'old', 'illinois', 'man', 'accused', 'of', 'fatally', 'stabbing', 'a', '6', 'year', 'old', 'boy', 'and', 'seriously', 'wounding', 'a', '32']

# %%
mystopwords = set(stopwords.words("english"))
print(len(mystopwords))
print(mystopwords)
# Out:
# 179
# {'yours', 'your', "it's", "mustn't", 'hadn', 'down', "hadn't", 'had', 'to', 'which', 'doesn', 'about', 'off', 'while', "needn't", 'she', 'own', 'has', 'theirs', 'doing', 'd', 'its', 'couldn', 'just', 'some', 'if', 'further', 't', 'do', 'when', 'it', 'that', 'why', 'how', 'ourselves', 'of', 'hasn', 'out', 'each', 'until', 'few', "don't", 'weren', "haven't", 'ain', 'for', 'too', 'o', 'yourself', 'can', "won't", 'only', 'ma', 'he', "mightn't", 'but', 'hers', 've', 'themselves', 'what', 'an', 'his', 'were', 'in', "you'd", 'between', 'm', 'will', 'through', 'me', 'by', 'we', 'above', 'mightn', 'same', 'herself', "you've", 'isn', 'from', 'shan', 'against', 'on', "shouldn't", 'very', 'be', 'did', 'don', 'any', "she's", 'all', 'been', 'where', 'who', 'being', 'as', 'other', 'won', "wouldn't", 'haven', 'not', 'their', 'below', 'was', 'didn', "you're", "hasn't", 'him', "you'll", 'now', "that'll", 'have', 'at', 'our', 'yourselves', 'once', 'after', 'both', 'himself', 'and', 'nor', 'or', "should've", 'again', 'more', 'i', 'does', 'so', 'then', 'into', 'them', 'such', "isn't", 'shouldn', 'itself', 'before', 'you', 'aren', 'under', 'because', "couldn't", 'ours', 'is', 'her', 'they', 'over', 'wasn', 'needn', 're', "weren't", 'with', 'am', 'll', 'having', 'these', 'the', "shan't", "aren't", 'most', 'up', 'here', 'during', "wasn't", 'are', 'my', 'should', 'there', "doesn't", 'y', 's', 'a', 'wouldn', 'whom', "didn't", 'those', 'mustn', 'no', 'myself', 'this', 'than'}

# %%
#stopwordsdict={}
#for stop in mystopwords:
#    stopwordsdict[stop] = 1

# %%
Bag=[]
for word in tokens:
    if word not in mystopwords and word.isnumeric()==False and len(word)>2:
        Bag.append(word)

# %%
print(len(Bag))
# Out:
# 25274

# %%
SnowStem = SnowballStemmer('english')
Lemmatiser = WordNetLemmatizer()

# %%
#Stembag = []
Lembag = []
for word in Bag:
    #Stembag.append(SnowStem.stem(word))
    Lembag.append(Lemmatiser.lemmatize(word))

# %%
print(Bag[:20])
#print(Stembag[:20])
print(Lembag[:20])
# Out:
# ['year', 'old', 'illinois', 'man', 'accused', 'fatally', 'stabbing', 'year', 'old', 'boy', 'seriously', 'wounding', 'year', 'old', 'woman', 'charged', 'hate', 'crime', 'sunday', 'police']
# ['year', 'old', 'illinois', 'man', 'accused', 'fatally', 'stabbing', 'year', 'old', 'boy', 'seriously', 'wounding', 'year', 'old', 'woman', 'charged', 'hate', 'crime', 'sunday', 'police']

# %%
mydict1 = {}
for word in Lembag:
    if word in mydict1.keys():
        mydict1[word] +=1
    else:
        mydict1[word] = 1

# %%
print(mydict1)
# Out:
# {'year': 58, 'old': 20, 'illinois': 3, 'man': 7, 'accused': 5, 'fatally': 1, 'stabbing': 1, 'boy': 7, 'seriously': 2, 'wounding': 6, 'woman': 50, 'charged': 3, 'hate': 8, 'crime': 10, 'sunday': 48, 'police': 16, 'allege': 1, 'singled': 1, 'victim': 11, 'islamic': 21, 'faith': 4, 'response': 18, 'war': 141, 'israel': 571, 'hamas': 391, 'recent': 26, 'day': 67, 'city': 61, 'federal': 3, 'authority': 32, 'high': 14, 'alert': 2, 'violence': 31, 'driven': 2, 'antisemitic': 1, 'islamophobic': 1, 'sentiment': 3, 'fbi': 5, 'official': 79, 'along': 33, 'jewish': 24, 'muslim': 14, 'group': 98, 'reported': 24, 'increase': 6, 'hateful': 1, 'threatening': 4, 'rhetoric': 3, 'chicago': 4, 'area': 30, 'case': 14, 'officer': 5, 'found': 9, 'late': 12, 'saturday': 32, 'morning': 13, 'home': 46, 'unincorporated': 1, 'plainfield': 2, 'township': 1, 'mile': 7, 'kilometer': 5, 'southwest': 1, 'county': 8, 'sheriff': 5, 'office': 21, 'said': 539, 'statement': 42, 'social': 9, 'medium': 34, 'pronounced': 1, 'dead': 18, 'hospital': 117, 'multiple': 9, 'stab': 1, 'wound': 2, 'expected': 20, 'survive': 2, 'according': 44, 'autopsy': 1, 'child': 41, 'showed': 10, 'stabbed': 1, 'dozen': 19, 'time': 38, '“detectives': 1, 'able': 12, 'determine': 1, 'brutal': 12, 'attack': 162, 'targeted': 11, 'suspect': 1, 'due': 10, 'going': 16, 'middle': 21, 'eastern': 5, 'conflict': 58, 'involving': 1, 'israeli': 279, 'called': 33, 'report': 20, 'landlord': 1, 'attacked': 12, 'knife': 1, 'adding': 7, 'ran': 2, 'bathroom': 1, 'continued': 7, 'fight': 8, 'suspected': 5, 'outside': 10, '“sitting': 1, 'upright': 1, 'ground': 58, 'near': 30, 'driveway': 1, 'residence”': 1, 'cut': 7, 'forehead': 1, 'joseph': 2, 'czuba': 3, 'first': 33, 'degree': 3, 'murder': 4, 'attempted': 2, 'two': 65, 'count': 2, 'aggravated': 1, 'battery': 7, 'deadly': 17, 'weapon': 6, 'custody': 1, 'awaiting': 2, 'court': 7, 'appearance': 1, 'attempt': 8, 'reach': 9, 'family': 33, 'member': 37, 'unsuccessful': 3, 'phone': 14, 'number': 22, 'unlisted': 1, 'message': 10, 'left': 16, 'possible': 17, 'relative': 8, 'online': 3, 'record': 6, 'immediately': 16, 'returned': 6, 'public': 13, 'defender': 1, 'return': 8, 'legal': 7, 'representation': 1, 'release': 16, 'name': 9, 'paternal': 1, 'uncle': 2, 'yousef': 2, 'hannon': 2, 'spoke': 17, 'news': 12, 'conference': 7, 'hosted': 2, 'chapter': 3, 'council': 20, 'american': 33, 'relation': 8, 'identified': 5, 'wadea': 2, 'fayoume': 1, 'palestinian': 202, 'recently': 5, 'turned': 5, 'organisation': 17, 'mother': 5, '“we': 33, 'animal': 2, 'human': 20, 'want': 20, 'people': 199, 'see': 18, 'feel': 6, 'deal': 8, 'emigrated': 1, 'work': 22, 'including': 53, 'school': 19, 'teacher': 2, 'civil': 8, 'liberty': 3, '“our': 5, 'worst': 1, 'nightmare”': 1, 'part': 24, 'disturbing': 1, 'spike': 1, 'call': 30, 'email': 2, 'since': 64, 'outbreak': 1, 'cited': 2, 'text': 3, 'exchanged': 2, 'among': 21, 'attacker': 8, 'made': 14, 'disparaging': 1, 'remark': 2, '“palestinians': 1, 'basically': 1, 'heart': 8, 'broken': 2, 'happening': 5, 'ahmed': 1, 'rehab': 1, 'executive': 3, 'director': 16, '“have': 3, 'also': 104, 'worry': 1, 'immediate': 23, 'safety': 11, 'life': 37, 'limb': 1, 'living': 12, 'free': 8, 'democracy': 4, 'world': 66, 'increased': 4, 'threat': 23, 'state': 101, 'communicating': 2, 'law': 21, 'enforcement': 2, 'reaching': 3, 'community': 23, 'religious': 10, 'leader': 52, 'offer': 4, 'support': 41, 'press': 16, 'democratic': 4, 'gov': 2, 'pritzker': 2, '“to': 5, 'take': 24, 'six': 14, 'bigotry': 2, 'nothing': 7, 'short': 6, 'evil': 3, 'heading': 3, 'instead': 2, 'parent': 4, 'wake': 7, 'without': 21, 'son': 2, 'every': 10, 'single': 5, 'illinoisan': 1, 'neighbor': 1, 'deserves': 2, 'live': 11, '”president': 1, 'joe': 28, 'biden': 77, 'echoed': 2, 'saying': 20, '“this': 16, 'horrific': 4, 'act': 18, 'place': 28, 'america': 10, 'stand': 20, 'fundamental': 4, 'value': 3, 'freedom': 3, 'fear': 12, 'pray': 1, 'believe': 6, '”fbi': 1, 'chris': 2, 'wray': 1, 'reporter': 1 ...

# %%
sortedDict = sorted(mydict1.items(),key=lambda x:x[1],reverse=True)
print(sortedDict[:100])
# Out:
# [('israel', 571), ('said', 539), ('gaza', 456), ('hamas', 391), ('israeli', 279), ('palestinian', 202), ('people', 199), ('attack', 162), ('war', 141), ('military', 139), ('militant', 123), ('hospital', 117), ('killed', 113), ('humanitarian', 110), ('civilian', 105), ('also', 104), ('state', 101), ('group', 98), ('would', 88), ('official', 79), ('biden', 77), ('president', 76), ('aid', 75), ('border', 72), ('minister', 69), ('day', 67), ('country', 67), ('world', 66), ('two', 65), ('since', 64), ('one', 64), ('strip', 63), ('security', 63), ('strike', 62), ('city', 61), ('force', 60), ('told', 59), ('year', 58), ('conflict', 58), ('ground', 58), ('territory', 57), ('india', 57), ('including', 53), ('leader', 52), ('woman', 50), ('say', 50), ('sunday', 48), ('southern', 48), ('west', 48), ('hostage', 48), ('million', 48), ('nation', 48), ('home', 46), ('health', 45), ('egypt', 45), ('need', 45), ('side', 45), ('region', 45), ('according', 44), ('week', 44), ('could', 44), ('airstrikes', 44), ('rocket', 44), ('international', 43), ('resolution', 43), ('statement', 42), ('october', 42), ('agency', 42), ('intelligence', 42), ('child', 41), ('support', 41), ('united', 41), ('ministry', 40), ('hundred', 40), ('thousand', 39), ('prime', 39), ('government', 39), ('time', 38), ('member', 37), ('life', 37), ('monday', 37), ('hezbollah', 37), ('netanyahu', 36), ('least', 36), ('terrorist', 36), ('order', 35), ('per', 35), ('death', 35), ('medium', 34), ('crisis', 34), ('must', 34), ('right', 34), ('along', 33), ('called', 33), ('first', 33), ('family', 33), ('american', 33), ('“we', 33), ('wounded', 33), ('water', 33)]

# %%
for x in sortedDict[:100]:
    print(x)
# Out:
# ('israel', 571)
# ('said', 539)
# ('gaza', 456)
# ('hamas', 391)
# ('israeli', 279)
# ('palestinian', 202)
# ('people', 199)
# ('attack', 162)
# ('war', 141)
# ('military', 139)
# ('militant', 123)
# ('hospital', 117)
# ('killed', 113)
# ('humanitarian', 110)
# ('civilian', 105)
# ('also', 104)
# ('state', 101)
# ('group', 98)
# ('would', 88)
# ('official', 79)
# ('biden', 77)
# ('president', 76)
# ('aid', 75)
# ('border', 72)
# ('minister', 69)
# ('day', 67)
# ('country', 67)
# ('world', 66)
# ('two', 65)
# ('since', 64)
# ('one', 64)
# ('strip', 63)
# ('security', 63)
# ('strike', 62)
# ('city', 61)
# ('force', 60)
# ('told', 59)
# ('year', 58)
# ('conflict', 58)
# ('ground', 58)
# ('territory', 57)
# ('india', 57)
# ('including', 53)
# ('leader', 52)
# ('woman', 50)
# ('say', 50)
# ('sunday', 48)
# ('southern', 48)
# ('west', 48)
# ('hostage', 48)
# ('million', 48)
# ('nation', 48)
# ('home', 46)
# ('health', 45)
# ('egypt', 45)
# ('need', 45)
# ('side', 45)
# ('region', 45)
# ('according', 44)
# ('week', 44)
# ('could', 44)
# ('airstrikes', 44)
# ('rocket', 44)
# ('international', 43)
# ('resolution', 43)
# ('statement', 42)
# ('october', 42)
# ('agency', 42)
# ('intelligence', 42)
# ('child', 41)
# ('support', 41)
# ('united', 41)
# ('ministry', 40)
# ('hundred', 40)
# ('thousand', 39)
# ('prime', 39)
# ('government', 39)
# ('time', 38)
# ('member', 37)
# ('life', 37)
# ('monday', 37)
# ('hezbollah', 37)
# ('netanyahu', 36)
# ('least', 36)
# ('terrorist', 36)
# ('order', 35)
# ('per', 35)
# ('death', 35)
# ('medium', 34)
# ('crisis', 34)
# ('must', 34)
# ('right', 34)
# ('along', 33)
# ('called', 33)
# ('first', 33)
# ('family', 33)
# ('american', 33)
# ('“we', 33)
# ('wounded', 33)
# ('water', 33)
