# %%
import re
from nltk.corpus import stopwords
from collections import defaultdict
from nltk.stem import SnowballStemmer
from nltk.stem import WordNetLemmatizer

# %%
filename = "Article 14.txt"
infile = open(filename,'r')
text = infile.read()
infile.close()

# %%
print(text[:100])
# Out:
# Article 14
#     Mr. Vice-President : We come to new article 14.
# (Amendment No. 504 was not moved.)

# %%
#Tokenise

unrefinedStr = re.sub(r'\—|\'|\`|\"|\||\.|\*|\[|\{|\}|\(|\)|\]|\;|\:|\,|\^|\=|\-|\+|\_|\!|\?|\/|\>|\<|\&|\\|\#|\n', r' ', text) # removing special characters

# %%
print(unrefinedStr)
# Out:
# Article 14     Mr  Vice President   We come to new article 14   Amendment No  504 was not moved        Shri H  V  Kamath  What about 13 A  That is  amendments 89  90 and 92 of List V       Mr  Vice President  That has been held over  I was referring to No  504       Now the motion is        That article 14 form part of the Constitution        Honourable Members have been supplied with a list which indicates the manner in which I propose to conduct the proceedings of the House  No  505 has been disallowed as being verbal  506 may be moved       Pandit Thakur Dass Bhargava  May I take the liberty of pointing out that my amendment  No  505  is not mercy verbal  It is an amendment of substance also       Mr  Vice President  Then I will give my ruling later on  Mr  Naziruddin Ahmad will carry on his work       Mr  Naziruddin Ahmad  West Bengal  Muslim   Mr  Vice President  I beg to move        That in clause  1  of article 14  after the words  greater than   the words  or of a kind other than  be inserted        Sir  clause  1  provides  I am reading only the material part         No person shall be subjected to a penalty greater than that which might have been inflicted under the law at the time of the commission of the offence        It guards against any punishment  greater than  is provide to be inflicted upon a person  I have attempted to insert after the words  greater than  the words  or other than  that which might have been inflicted  There are many cases where a punishment of fine only is provided  Suppose a man is fined one lakh of rupees  An Appellate Court may turn it to an imprisonment during the sitting of the Court  That will violate the provision that where fine alone is provided for  an imprisonment may be substituted on the ground that it is not  greater than  that  My amendment seeks to limit the powers of Courts to inflict punishment not only as to the extent but also to the kind  There are different kinds of punishments  fine  imprisonment  whipping  forfeiture and hanging and the like where only a particular kind of punishment is specifically provided  you should not award any punishment other than that  That is in short the effect of this amendment  Where whipping alone is provided  You cannot award a fine  Where fine alone is provided  you cannot award imprisonment or whipping or forfeiture  Where forfeiture of movables only a provided  you cannot forfeit immovables  Where forfeiture of articles relating to which crime has been committed is provided  you cannot forfeit other kinds of things  So if we leave the powers of the courts as in the clause it gives the Court the power to give any punishment not sanctioned by law  If clause  1  is to be retained  the Court should also be limited to the class of punishment provided  To me it seems that there is here a lacuna rather oversight which should be corrected       Mr  Vice President  As regards amendment No  505  I can allow the Member to move the second part of it  Pandit Thakur Dass Bhargava       Pandit Thakur Das Bhargava   Sir  I beg to move        That in clause  1  of article 14  for the words  under the law at the time of the commission  the words  under the law in force at the time of the commission  be substituted        Sir  if you kindly examine the definition of the expression  law in force  as given in the explanation under article 307  it would appear that the words  the law  and the words  the law in force  have different meanings  Moreover as the words in the previous part of the article also appear as  law in force   it is very necessary and proper in this juxtaposition that the amendment that I have suggested should be accepted  That is all I have to submit       Mr  Vice President  Amendment Nos  507  508 and 511 are of the same import  The most comprehensive one  i  e  No 507  may be moved   Amendments Nos  507  508 and 511 were not moved        Amendments Nos  509 and 510 are of similar import and may be moved together  They are in the n ...

# %%
tokens = unrefinedStr.split()

# %%
print(len(tokens))
print(tokens[:20])#print(tokens[0:20:1])
# Out:
# 16174
# ['\ufeffArticle', '14', 'Mr', 'Vice', 'President', 'We', 'come', 'to', 'new', 'article', '14', 'Amendment', 'No', '504', 'was', 'not', 'moved', 'Shri', 'H', 'V']

# %%
tokens = [myword.lower() for myword in tokens]

# %%
print(tokens[:20])
# Out:
# ['\ufeffarticle', '14', 'mr', 'vice', 'president', 'we', 'come', 'to', 'new', 'article', '14', 'amendment', 'no', '504', 'was', 'not', 'moved', 'shri', 'h', 'v']

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/prabhav/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
mystopwords = set(stopwords.words("english"))
print(len(mystopwords))
print(mystopwords)
# Out:
# 179
# {'we', "you're", 'them', 'ain', 'it', 'before', "hadn't", "that'll", "you'll", 'ourselves', 'am', 'herself', 'into', "you'd", 'over', 'not', 'while', 'doing', 'through', 'll', "needn't", 'our', 'now', 'by', 'doesn', 'haven', 'won', 'had', 'further', 'be', 're', "should've", 'these', 'her', 'under', 'how', "won't", 'didn', 'up', 'for', 'any', 'yourselves', 'few', 'when', 'as', 'being', 'mightn', 'your', 'is', 'so', "doesn't", 'hers', 'i', 'then', 'and', 'same', 'shouldn', 'nor', 'such', 'does', 'of', 'do', 'each', 'those', "wouldn't", 'was', 't', 'to', 'd', 'itself', 'off', 'a', 'both', 'my', 'me', 'his', 'couldn', 'can', 'themselves', 'again', "mightn't", 'until', 'hasn', 'below', 'against', 'the', 'were', 'have', 'what', 'he', 'between', 'wasn', "it's", 'its', 'which', 'wouldn', "don't", 'has', 'there', "haven't", 'she', 'from', 'just', 'about', 'an', 'ma', 'their', "wasn't", 'yourself', 'own', 'you', 'mustn', "you've", "shan't", 'but', 'with', 'him', "mustn't", 'y', 'all', 'in', 'why', 'needn', 'other', 'himself', 'don', 'out', 've', 'myself', 'who', 'if', "isn't", 'ours', 'will', 'most', 'where', 'whom', 's', "weren't", 'or', 'yours', 'too', 'o', 'after', 'only', 'than', 'theirs', 'shan', 'no', 'are', 'some', 'at', 'above', 'should', 'hadn', 'because', 'they', 'down', 'during', 'been', 'did', 'once', 'very', "she's", 'on', 'having', "aren't", 'more', "shouldn't", 'isn', 'aren', 'here', "couldn't", "didn't", 'that', 'this', "hasn't", 'weren', 'm'}

# %%
#stopwordsdict={}
#for stop in mystopwords:
#    stopwordsdict[stop] = 1

# %%
Bag=[]
for word in tokens:
    if word not in mystopwords and word.isnumeric()==False and len(word)>2:
        Bag.append(word)

# %%
print(len(Bag))
# Out:
# 7375

# %%
SnowStem = SnowballStemmer('english')
Lemmatiser = WordNetLemmatizer()

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /home/prabhav/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
Stembag = []
Lembag = []
for word in Bag:
    Stembag.append(SnowStem.stem(word))
    Lembag.append(Lemmatiser.lemmatize(word))

# %%
print(Bag[:20])
print(Stembag[:20])
print(Lembag[:20])
# Out:
# ['\ufeffarticle', 'vice', 'president', 'come', 'new', 'article', 'amendment', 'moved', 'shri', 'kamath', 'amendments', 'list', 'vice', 'president', 'held', 'referring', 'motion', 'article', 'form', 'part']
# ['\ufeffarticl', 'vice', 'presid', 'come', 'new', 'articl', 'amend', 'move', 'shri', 'kamath', 'amend', 'list', 'vice', 'presid', 'held', 'refer', 'motion', 'articl', 'form', 'part']
# ['\ufeffarticle', 'vice', 'president', 'come', 'new', 'article', 'amendment', 'moved', 'shri', 'kamath', 'amendment', 'list', 'vice', 'president', 'held', 'referring', 'motion', 'article', 'form', 'part']

# %%
mydict = {}
for word in Stembag:
    if word in mydict.keys():
        mydict[word] +=1
    else:
        mydict[word] = 1

# %%
mydict1 = {}
for word in Lembag:
    if word in mydict1.keys():
        mydict1[word] +=1
    else:
        mydict1[word] = 1

# %%
print(mydict)
# Out:
# {'\ufeffarticl': 1, 'vice': 93, 'presid': 98, 'come': 27, 'new': 8, 'articl': 175, 'amend': 159, 'move': 68, 'shri': 60, 'kamath': 12, 'list': 22, 'held': 2, 'refer': 16, 'motion': 9, 'form': 25, 'part': 26, 'constitut': 33, 'honour': 37, 'member': 29, 'suppli': 2, 'indic': 2, 'manner': 2, 'propos': 3, 'conduct': 3, 'proceed': 3, 'hous': 58, 'disallow': 4, 'verbal': 4, 'may': 69, 'pandit': 9, 'thakur': 4, 'dass': 3, 'bhargava': 4, 'take': 18, 'liberti': 3, 'point': 31, 'merci': 2, 'substanc': 1, 'also': 25, 'give': 24, 'rule': 8, 'later': 3, 'naziruddin': 10, 'ahmad': 9, 'carri': 9, 'work': 20, 'west': 6, 'bengal': 5, 'muslim': 5, 'beg': 11, 'claus': 64, 'word': 80, 'greater': 6, 'kind': 16, 'insert': 10, 'sir': 79, 'provid': 25, 'read': 11, 'materi': 1, 'person': 17, 'shall': 71, 'subject': 32, 'penalti': 1, 'might': 14, 'inflict': 6, 'law': 41, 'time': 32, 'commiss': 5, 'offenc': 14, 'guard': 1, 'punish': 33, 'upon': 10, 'attempt': 2, 'mani': 5, 'case': 13, 'fine': 8, 'suppos': 4, 'man': 22, 'one': 48, 'lakh': 2, 'rupe': 1, 'appel': 4, 'court': 29, 'turn': 1, 'imprison': 5, 'sit': 1, 'violat': 4, 'provis': 24, 'alon': 8, 'substitut': 11, 'ground': 10, 'seek': 8, 'limit': 12, 'power': 29, 'extent': 4, 'differ': 4, 'whip': 3, 'forfeitur': 4, 'hang': 2, 'like': 19, 'particular': 24, 'specif': 1, 'award': 4, 'short': 2, 'effect': 15, 'cannot': 23, 'movabl': 1, 'forfeit': 2, 'immov': 1, 'relat': 10, 'crime': 4, 'commit': 3, 'thing': 10, 'leav': 5, 'sanction': 1, 'retain': 1, 'class': 12, 'seem': 5, 'lacuna': 4, 'rather': 4, 'oversight': 1, 'correct': 6, 'regard': 17, 'allow': 12, 'second': 7, 'das': 8, 'forc': 18, 'examin': 5, 'definit': 3
': 1, 'clap': 1, 'feeble': 1, 'aye': 1, 'lost': 4, 'difficulty': 4, 'crave': 1, 'indulgent': 1, 'attention': 6, 'chairman': 2, 'drafting': 6, 'committee': 8, 'raising': 1, 'restrict': 1, 'strictly': 1, 'relevancy': 1, 'deal': 14, 'important': 8, 'principle': 14, 'amend': 1, 'run': 2, 'follows': 1, 'punished': 13, 'sacred': 1, 'sentiment': 1, 'prompted': 1, 'introduction': 1, 'considered': 8, 'view': 5, 'loop': 1, 'hole': 1, 'sweeping': 1, 'legally': 1, 'twice': 5, 'circumstance': 2, 'relevant': 2, 'principal': 1, 'subject': 30, 'find': 27, 'place': 20, 'section': 13, 'sub': 7, 'enacted': 1, 'krishnamachari': 13, 'enactmente': 1, 'anything': 7, 'else': 3, 'already': 13, 'referred': 4, 'saved': 1, 'existing': 3, 'enactment': 1, 'subordinate': 1, 'legislature': 37, 'handy': 1, 'consideration': 9, 'pretend': 1, 'embodied': 1, 'sound': 2, 'even': 19, 'binding': 4, 'soundest': 1, 'proposition': 2, 'sovereign': 2, 'submitting': 2, 'certain': 18, 'worthy': 1, 'often': 7, 'happens': 7, 'example': 4, 'general': 31, 'think': 43, 'acceptable': 1, 'jurisdiction': 14, 'ordinary': 4, 'experience': 5, 'judge': 1, 'appeal': 4, 'high': 1, 'privy': 1, 'council': 1, 'federal': 1, 'future': 3, 'supreme': 1, 'conviction': 10, 'without': 17, 'meantime': 1, 'convicted': 8, 'say': 46, 'trial': 13, 'revisional': 1, 'absolutely': 5, 'question': 22, 'tried': 6, 'magistrate': 2, 'found': 8, 'try': 5, 'done': 3, 'enact': 1, 'compe ...

# %%
sortedDict = sorted(mydict.items(),key=lambda x:x[1],reverse=True)
print(sortedDict[:100])
# Out:
# [('articl', 175), ('amend', 159), ('state', 115), ('presid', 98), ('vice', 93), ('right', 92), ('word', 80), ('sir', 79), ('shall', 71), ('may', 69), ('move', 68), ('claus', 64), ('shri', 60), ('hous', 58), ('fundament', 53), ('trade', 49), ('one', 48), ('would', 48), ('say', 48), ('think', 43), ('commerc', 42), ('law', 41), ('parliament', 38), ('honour', 37), ('legislatur', 37), ('servic', 36), ('accept', 34), ('constitut', 33), ('punish', 33), ('subject', 32), ('time', 32), ('women', 32), ('point', 31), ('general', 31), ('put', 30), ('india', 30), ('member', 29), ('court', 29), ('power', 29), ('matter', 29), ('traffic', 28), ('come', 27), ('find', 27), ('therefor', 27), ('made', 27), ('provinc', 27), ('part', 26), ('name', 26), ('form', 25), ('also', 25), ('provid', 25), ('give', 24), ('provis', 24), ('particular', 24), ('public', 24), ('cannot', 23), ('suggest', 23), ('place', 23), ('ambedkar', 23), ('list', 22), ('man', 22), ('question', 22), ('stand', 22), ('impos', 22), ('begar', 22), ('certain', 21), ('peopl', 21), ('want', 21), ('religion', 21), ('work', 20), ('import', 20), ('countri', 20), ('like', 19), ('restrict', 19), ('even', 19), ('concern', 19), ('take', 18), ('forc', 18), ('convict', 18), ('friend', 18), ('human', 18), ('union', 18), ('labour', 18), ('person', 17), ('regard', 17), ('deal', 17), ('without', 17), ('make', 17), ('subramaniam', 17), ('discrimin', 17), ('compulsori', 17), ('social', 17), ('refer', 16), ('kind', 16), ('necessari', 16), ('taken', 16), ('intercours', 16), ('free', 16), ('legisl', 16), ('shah', 16)]

# %%
for x in sortedDict[:100]:
    print(x)
# Out:
# ('articl', 175)
# ('amend', 159)
# ('state', 115)
# ('presid', 98)
# ('vice', 93)
# ('right', 92)
# ('word', 80)
# ('sir', 79)
# ('shall', 71)
# ('may', 69)
# ('move', 68)
# ('claus', 64)
# ('shri', 60)
# ('hous', 58)
# ('fundament', 53)
# ('trade', 49)
# ('one', 48)
# ('would', 48)
# ('say', 48)
# ('think', 43)
# ('commerc', 42)
# ('law', 41)
# ('parliament', 38)
# ('honour', 37)
# ('legislatur', 37)
# ('servic', 36)
# ('accept', 34)
# ('constitut', 33)
# ('punish', 33)
# ('subject', 32)
# ('time', 32)
# ('women', 32)
# ('point', 31)
# ('general', 31)
# ('put', 30)
# ('india', 30)
# ('member', 29)
# ('court', 29)
# ('power', 29)
# ('matter', 29)
# ('traffic', 28)
# ('come', 27)
# ('find', 27)
# ('therefor', 27)
# ('made', 27)
# ('provinc', 27)
# ('part', 26)
# ('name', 26)
# ('form', 25)
# ('also', 25)
# ('provid', 25)
# ('give', 24)
# ('provis', 24)
# ('particular', 24)
# ('public', 24)
# ('cannot', 23)
# ('suggest', 23)
# ('place', 23)
# ('ambedkar', 23)
# ('list', 22)
# ('man', 22)
# ('question', 22)
# ('stand', 22)
# ('impos', 22)
# ('begar', 22)
# ('certain', 21)
# ('peopl', 21)
# ('want', 21)
# ('religion', 21)
# ('work', 20)
# ('import', 20)
# ('countri', 20)
# ('like', 19)
# ('restrict', 19)
# ('even', 19)
# ('concern', 19)
# ('take', 18)
# ('forc', 18)
# ('convict', 18)
# ('friend', 18)
# ('human', 18)
# ('union', 18)
# ('labour', 18)
# ('person', 17)
# ('regard', 17)
# ('deal', 17)
# ('without', 17)
# ('make', 17)
# ('subramaniam', 17)
# ('discrimin', 17)
# ('compulsori', 17)
# ('social', 17)
# ('refer', 16)
# ('kind', 16)
# ('necessari', 16)
# ('taken', 16)
# ('intercours', 16)
# ('free', 16)
# ('legisl', 16)
# ('shah', 16)

# %%
sortedDict = sorted(mydict1.items(),key=lambda x:x[1],reverse=True)
print(sortedDict[:100])
# Out:
# [('article', 175), ('amendment', 156), ('state', 112), ('vice', 93), ('right', 92), ('president', 91), ('sir', 79), ('word', 76), ('shall', 71), ('may', 69), ('clause', 64), ('shri', 60), ('house', 58), ('fundamental', 53), ('trade', 49), ('one', 48), ('would', 48), ('say', 46), ('think', 43), ('commerce', 42), ('law', 39), ('moved', 38), ('parliament', 38), ('honourable', 37), ('legislature', 37), ('service', 36), ('constitution', 32), ('time', 32), ('woman', 32), ('general', 31), ('subject', 30), ('india', 30), ('member', 29), ('court', 29), ('matter', 29), ('power', 28), ('traffic', 28), ('find', 27), ('therefore', 27), ('made', 27), ('province', 27), ('part', 26), ('move', 26), ('also', 25), ('put', 25), ('form', 24), ('provision', 24), ('point', 24), ('public', 24), ('cannot', 23), ('name', 23), ('ambedkar', 23), ('come', 22), ('list', 22), ('man', 22), ('question', 22), ('begar', 22), ('people', 21), ('religion', 21), ('give', 20), ('work', 20), ('punishment', 20), ('place', 20), ('country', 20), ('accept', 20), ('particular', 19), ('even', 19), ('want', 19), ('like', 18), ('certain', 18), ('friend', 18), ('union', 18), ('provided', 17), ('regard', 17), ('without', 17), ('subramaniam', 17), ('compulsory', 17), ('social', 17), ('necessary', 16), ('taken', 16), ('intercourse', 16), ('free', 16), ('restriction', 16), ('shah', 16), ('take', 15), ('kind', 15), ('person', 15), ('another', 15), ('madras', 15), ('know', 15), ('human', 15), ('discrimination', 15), ('national', 15), ('might', 14), ('offence', 14), ('deal', 14), ('principle', 14), ('jurisdiction', 14), ('nothing', 14), ('well', 14)]

# %%
for x in sortedDict[:100]:
    print(x)
# Out:
# ('article', 175)
# ('amendment', 156)
# ('state', 112)
# ('vice', 93)
# ('right', 92)
# ('president', 91)
# ('sir', 79)
# ('word', 76)
# ('shall', 71)
# ('may', 69)
# ('clause', 64)
# ('shri', 60)
# ('house', 58)
# ('fundamental', 53)
# ('trade', 49)
# ('one', 48)
# ('would', 48)
# ('say', 46)
# ('think', 43)
# ('commerce', 42)
# ('law', 39)
# ('moved', 38)
# ('parliament', 38)
# ('honourable', 37)
# ('legislature', 37)
# ('service', 36)
# ('constitution', 32)
# ('time', 32)
# ('woman', 32)
# ('general', 31)
# ('subject', 30)
# ('india', 30)
# ('member', 29)
# ('court', 29)
# ('matter', 29)
# ('power', 28)
# ('traffic', 28)
# ('find', 27)
# ('therefore', 27)
# ('made', 27)
# ('province', 27)
# ('part', 26)
# ('move', 26)
# ('also', 25)
# ('put', 25)
# ('form', 24)
# ('provision', 24)
# ('point', 24)
# ('public', 24)
# ('cannot', 23)
# ('name', 23)
# ('ambedkar', 23)
# ('come', 22)
# ('list', 22)
# ('man', 22)
# ('question', 22)
# ('begar', 22)
# ('people', 21)
# ('religion', 21)
# ('give', 20)
# ('work', 20)
# ('punishment', 20)
# ('place', 20)
# ('country', 20)
# ('accept', 20)
# ('particular', 19)
# ('even', 19)
# ('want', 19)
# ('like', 18)
# ('certain', 18)
# ('friend', 18)
# ('union', 18)
# ('provided', 17)
# ('regard', 17)
# ('without', 17)
# ('subramaniam', 17)
# ('compulsory', 17)
# ('social', 17)
# ('necessary', 16)
# ('taken', 16)
# ('intercourse', 16)
# ('free', 16)
# ('restriction', 16)
# ('shah', 16)
# ('take', 15)
# ('kind', 15)
# ('person', 15)
# ('another', 15)
# ('madras', 15)
# ('know', 15)
# ('human', 15)
# ('discrimination', 15)
# ('national', 15)
# ('might', 14)
# ('offence', 14)
# ('deal', 14)
# ('principle', 14)
# ('jurisdiction', 14)
# ('nothing', 14)
# ('well', 14)
